# %% [markdown]
# ##python libraries

# %%
import pandas as pd

# %%
pd.read_csv(filepath_or_buffer="telecommunications.csv")
# Out:
#      Telecom__1 Telecom__2 Telecom__3 Telecom__4 Telecom__5 Telecom__6  \
# 0          9981       5279       6843       seek   approach       2429
# 1          idea       4614        763      while     relate       3625
# 2          7151       term        948       6334       4145       less
# 3          area       1649       upon       3212       4644     market
# 4          6621       7584        382       1265   practice       9579
# ...         ...        ...        ...        ...        ...        ...
# 9995         be        322      blood       5203       9390       find
# 9996       3094       1079       6036  everybody       upon       8658
# 9997        784        boy       1049       3103       7398       5025
# 9998      close       9124       4624       5619       2590    protect
# 9999   personal       7097       1227       2114       4404       6944
#
#      Telecom__7 Telecom__8    Telecom__9 Telecom__10  ... Telecom__31  \
# ...
